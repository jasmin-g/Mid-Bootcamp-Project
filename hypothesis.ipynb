# %%
import pandas as pd
import numpy as np
import pymysql 
from sqlalchemy import create_engine 
from getpass import getpass
from scipy.stats import ttest_1samp

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/lifestyle_sql'
engine = create_engine(connection_string)

# %%
query = 'SELECT * FROM lifestyle'
data = pd.read_sql_query(query, engine)
data.head()
# Out:
#   gender  age characteristics_people  year  smokers  ex_smokers  never_smoked  \
# 0    all  all                    all  2014     24.4        29.3          46.3
# 1    all  all                    all  2016     22.2        30.0          47.9
# 2    all  all                    all  2018     20.7        30.4          48.9
# 3    all  all               ed. lv 1  2014     28.5        37.4          34.1
# 4    all  all               ed. lv 1  2016     27.1        37.6          35.3
#
#    drinker  ex_drinker  never_drank  heavy_drinker  max_1_glass_per_day  \
# 0     77.2        11.2         11.6           11.8                 41.0
# 1     76.0        11.4         12.6           11.1                 42.9
# 2     75.8        11.2         13.0           11.0                 43.8
# 3     70.1        16.4         13.5           10.9                 49.9
# 4     68.0        17.7         14.3           11.4                 52.9
#
#    underweight  normal_weight  overweight  \
# ...

# %%
data.shape
# Out:
# (507, 18)

# %% [markdown]
# Hypothesis young men (<65) in the lowest income group drink more than men >65

# %%
H0 = data[data['gender']=='male']
H0 = H0[(H0['age']=='<25') |(H0['age']=='25-45') | (H0['age']=='45-65')]
H0 = H0[H0['characteristics_people']=='inco 1st 20%']
H0
# Out:
#     gender    age characteristics_people  year  smokers  ex_smokers  \
# 216   male    <25           inco 1st 20%  2014     32.0         5.8
# 217   male    <25           inco 1st 20%  2016     26.5         5.3
# 218   male    <25           inco 1st 20%  2018     22.8         7.5
# 249   male  25-45           inco 1st 20%  2014     48.4        15.4
# 250   male  25-45           inco 1st 20%  2016     43.5        15.4
# 251   male  25-45           inco 1st 20%  2018     42.1        18.5
# 284   male  45-65           inco 1st 20%  2014     45.7        27.7
# 285   male  45-65           inco 1st 20%  2016     45.5        27.6
# 286   male  45-65           inco 1st 20%  2018     51.3        24.8
#
#      never_smoked  drinker  ex_drinker  never_drank  heavy_drinker  \
# 216          62.2     64.7        11.3         24.0           28.1
# 217          68.2     61.4         9.4         29.1           25.7
# 218          69.7     58.2         7.4         34.4           26.5
# ...

# %%
H1 = data[data['gender']=='male']
H1 = H1[H1['age']=='>65']
H1 = H1[H1['characteristics_people']=='inco 1st 20%']
H1
# Out:
#     gender  age characteristics_people  year  smokers  ex_smokers  \
# 319   male  >65           inco 1st 20%  2014     20.4        63.4
# 320   male  >65           inco 1st 20%  2016     28.3        56.3
# 321   male  >65           inco 1st 20%  2018     20.8        51.8
#
#      never_smoked  drinker  ex_drinker  never_drank  heavy_drinker  \
# 319          16.1     78.7        13.5          7.9            0.0
# 320          15.4     58.0        27.1         14.8            0.0
# 321          27.4     75.5        17.5          7.0            9.0
#
#      max_1_glass_per_day  underweight  normal_weight  overweight  \
# 319                 44.4          0.0            0.0         0.0
# 320                 57.5          0.0           41.6        58.4
# 321                 50.4          1.6           36.5        62.0
#
#      sufficient_moderate_intensive-effort  7_days_per_week_sufficient_fruit  \
# 319                                   0.0                              35.0
# ...

# %%
H0_mean = H0['drinker'].mean()

# %%
stat, pval = ttest_1samp(H1['drinker'], H0_mean)

# %%
print('stat is  ', stat)
print('pvalue for the one-tailed test is ', pval/2)
# Out:
# stat is   0.36960276338514714
# pvalue for the one-tailed test is  0.373572086235961

# %% [markdown]
# the p value is above 0.05 so I have to reject my hypothesis
